# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")
## LANGHCAIN TRACKING 
os.environ["LANGCHAIN_API_KEY"]=os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"]="true"
os.environ["LANGCHAIN_PROJECT"]=os.getenv("LANGCHAIN_PROJECT")

# %%
# llm model 
from langchain_groq import ChatGroq

model = ChatGroq(
    model="llama3-8b-8192"
)

print(model)
# Out:
# output_version=None profile={'max_input_tokens': 8192, 'max_output_tokens': 8192, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True} client=<groq.resources.chat.completions.Completions object at 0x0000020CAC0FADD0> async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x0000020CAC0FBD30> model_name='llama3-8b-8192' model_kwargs={} groq_api_key=SecretStr('**********') groq_api_base=None groq_proxy=None

# %%
# respose

res = model.invoke("what is agentic ai")

print(res.content)
# Out:
# Agentic AI refers to a type of artificial intelligence (AI) that exhibits autonomous, goal-oriented behavior, similar to that of a human agent. Agentic AI systems are designed to take initiative, make decisions, and act independently to achieve their objectives, often in complex and dynamic environments.
#
# Key characteristics of agentic AI include:
#
# 1. **Autonomy**: Agentic AI systems can operate independently, making decisions and taking actions without direct human intervention.
# 2. **Goal-oriented behavior**: Agentic AI systems are designed to achieve specific goals or objectives, which can be either pre-programmed or learned through experience.
# 3. **Self-awareness**: Agentic AI systems may possess a degree of self-awareness, allowing them to reflect on their own actions, goals, and motivations.
# 4. **Proactive behavior**: Agentic AI systems can take the initiative to act, rather than simply responding to external stimuli.
# 5. **Adaptability**: Agentic AI systems can adapt to changing circumstances and adjust their behavior accordingly.
#
# Agentic AI can be categorized into several types, including:
#
# 1. **Narrow or weak agentic AI**: This type of AI is designed to perform a specific task, such as playing chess or recognizing images.
# 2. **General or strong agentic AI**: This type of AI is designed to perform any intellectual task that a human can, with potentially unpredictable outcomes.
# 3. **Superagentic AI**: This type of AI is hypothetical and far beyond current capabilities, potentially possessing abilities that surpass human intelligence and capabilities.
#
# Agentic AI has the potential to revolutionize various industries, including:
#
# 1. **Healthcare**: Agentic AI systems can assist in diagnosis, treatment, and patient care, making decisions and acting autonomously.
# 2. **Transportation**: Agentic AI systems can control autonomous vehicles, making decisions in real-time to ensure safe and efficient transportation.
# 3. **Finance**: Agentic AI systems can manage portfolios, make investment decisions, and respond to market fluctuations.
#
# However, the development and deployment of agentic AI raise significant concerns, including:
#
# 1. **Safety and control**: Agentic AI systems can pose risks if they act unpredictably or autonomously, potentially leading to unintended consequences.
# 2. **Ethics and accountability**: Agentic AI systems can raise questions about responsibility and accountability, as they may make decisions that have significant impacts on individuals and society.
# 3. **Job displacement**: Agentic AI systems can automate tasks, potentially displacing human workers and raising concerns about job security.
#
# In conclusion, agentic AI is a rapidly evolving field that holds great promise for revolutionizing various industries, but also raises significant concerns about safety, ethics, and accountability. As we continue to develop and deploy agentic AI, it is essential to address these concerns and ensure that these systems are designed and deployed responsibly.

# %%
# chatprompttemplets
from langchain_core.prompts import ChatPromptTemplate
prompt = ChatPromptTemplate.from_messages([
    ("system","you are a assistents"),
    ("user","{inputs}")
])

# %%
# chain 
chain = prompt|model
result =chain.invoke({"inputs":"What is ai"})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # chain
# ----> 2 chain = prompt|model
#       3 result =chain.invoke({"inputs:What is ai"})
#
# NameError: name 'prompt' is not defined

# %%
# stroutputs parse 
from langchain_core.output_parsers  import StrOutputParser
output=StrOutputParser()
chain=prompt|model|output

# %%
result = chain.invoke({"inputs": "What is AI"})
print(result)
# Out:
# I'd be happy to explain what AI is.
#
# **What is Artificial Intelligence (AI)?**
#
# Artificial Intelligence (AI) refers to the simulation of human intelligence in machines that are programmed to think and learn like humans. The term may also be applied to any machine that exhibits traits associated with a human mind such as learning and problem-solving.
#
# **History of AI**
#
# The concept of AI has been around since the mid-20th century, with the term "Artificial Intelligence" first being coined in 1956 by computer scientist John McCarthy. However, the field of AI has a long and varied history that dates back to ancient civilizations.
#
# **Key Aspects of AI**
#
# AI is characterized by several key aspects, including:
#
# 1. **Machine Learning (ML)**: AI systems can learn from data, identify patterns, and make predictions or decisions based on that data.
# 2. **Natural Language Processing (NLP)**: AI systems can understand, interpret, and generate human language.
# 3. **Computer Vision**: AI systems can interpret and understand visual data from images and videos.
# 4. **Expert Systems**: AI systems can mimic the decision-making abilities of a human expert in a particular field.
# 5. **Robotics**: AI systems can control robots and other mechanical devices to perform tasks.
#
# **Types of AI**
#
# There are several types of AI, including:
#
# 1. **Narrow or Weak AI**: Designed to perform a specific task, such as facial recognition or language translation.
# 2. **General or Strong AI**: A hypothetical AI system that possesses the ability to understand, learn, and apply knowledge across a wide range of tasks.
# 3. **Superintelligence**: An AI system that significantly surpasses human intelligence in all domains.
#
# **Applications of AI**
#
# AI has a wide range of applications, including:
#
# 1. **Virtual Assistants**: AI-powered virtual assistants, such as Siri, Alexa, and Google Assistant.
# 2. **Image Recognition**: AI-powered image recognition systems, such as facial recognition and object detection.
# 3. **Predictive Maintenance**: AI-powered predictive maintenance systems that predict equipment failure and schedule maintenance.
# 4. **Healthcare**: AI-powered healthcare systems that analyze medical data and provide personalized treatment recommendations.
# 5. **Autonomous Vehicles**: AI-powered autonomous vehicles that navigate and make decisions without human input.
#
# **Benefits and Challenges of AI**
#
# The benefits of AI include:
#
# 1. **Improved Efficiency**: AI systems can automate tasks, freeing up human resources for more complex and creative work.
# 2. **Enhanced Decision-Making**: AI systems can analyze large datasets and provide insights that inform decision-making.
# 3. **Increased Productivity**: AI systems can automate tasks, leading to increased productivity and reduced costs.
#
# However, AI also poses several challenges, including:
#
# 1. **Job Displacement**: AI systems may displace human workers, particularly in sectors where tasks are repetitive or can be easily automated.
# 2. **Bias and Fairness**: AI systems can perpetuate biases and discriminate against certain groups of people.
# 3. **Security and Privacy**: AI systems can be vulnerable to cyber attacks and data breaches.
#
# I hope this provides a comprehensive introduction to what AI is!

# %%
print(result)
# Out:
# I'd be happy to explain what AI is.
#
# **What is Artificial Intelligence (AI)?**
#
# Artificial Intelligence (AI) refers to the simulation of human intelligence in machines that are programmed to think and learn like humans. The term may also be applied to any machine that exhibits traits associated with a human mind such as learning and problem-solving.
#
# **History of AI**
#
# The concept of AI has been around since the mid-20th century, with the term "Artificial Intelligence" first being coined in 1956 by computer scientist John McCarthy. However, the field of AI has a long and varied history that dates back to ancient civilizations.
#
# **Key Aspects of AI**
#
# AI is characterized by several key aspects, including:
#
# 1. **Machine Learning (ML)**: AI systems can learn from data, identify patterns, and make predictions or decisions based on that data.
# 2. **Natural Language Processing (NLP)**: AI systems can understand, interpret, and generate human language.
# 3. **Computer Vision**: AI systems can interpret and understand visual data from images and videos.
# 4. **Expert Systems**: AI systems can mimic the decision-making abilities of a human expert in a particular field.
# 5. **Robotics**: AI systems can control robots and other mechanical devices to perform tasks.
#
# **Types of AI**
#
# There are several types of AI, including:
#
# 1. **Narrow or Weak AI**: Designed to perform a specific task, such as facial recognition or language translation.
# 2. **General or Strong AI**: A hypothetical AI system that possesses the ability to understand, learn, and apply knowledge across a wide range of tasks.
# 3. **Superintelligence**: An AI system that significantly surpasses human intelligence in all domains.
#
# **Applications of AI**
#
# AI has a wide range of applications, including:
#
# 1. **Virtual Assistants**: AI-powered virtual assistants, such as Siri, Alexa, and Google Assistant.
# 2. **Image Recognition**: AI-powered image recognition systems, such as facial recognition and object detection.
# 3. **Predictive Maintenance**: AI-powered predictive maintenance systems that predict equipment failure and schedule maintenance.
# 4. **Healthcare**: AI-powered healthcare systems that analyze medical data and provide personalized treatment recommendations.
# 5. **Autonomous Vehicles**: AI-powered autonomous vehicles that navigate and make decisions without human input.
#
# **Benefits and Challenges of AI**
#
# The benefits of AI include:
#
# 1. **Improved Efficiency**: AI systems can automate tasks, freeing up human resources for more complex and creative work.
# 2. **Enhanced Decision-Making**: AI systems can analyze large datasets and provide insights that inform decision-making.
# 3. **Increased Productivity**: AI systems can automate tasks, leading to increased productivity and reduced costs.
#
# However, AI also poses several challenges, including:
#
# 1. **Job Displacement**: AI systems may displace human workers, particularly in sectors where tasks are repetitive or can be easily automated.
# 2. **Bias and Fairness**: AI systems can perpetuate biases and discriminate against certain groups of people.
# 3. **Security and Privacy**: AI systems can be vulnerable to cyber attacks and data breaches.
#
# I hope this provides a comprehensive introduction to what AI is!
