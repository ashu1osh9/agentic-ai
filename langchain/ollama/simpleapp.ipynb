# %%
import os
from dotenv import load_dotenv
load_dotenv()

# %%
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")
## LANGHCAIN TRACKING 
os.environ["LANGCHAIN_TRACING_V2"]="true"
os.environ["LANGCHAIN_PROJECT"]=os.getenv("LANGCHAIN_PROJECT")

# %%
# llm model 
from langchain_groq import ChatGroq
model = ChatGroq("model=")
print(model)
# Out:
#   Cell In[2], line 3
#     model = ChatGroq(})
#                      ^
# SyntaxError: closing parenthesis '}' does not match opening parenthesis '('

# %%
# response
model.invoke("what is agentic ai")
# Out:
# Hello

# %%
# chatprompttemplets
from langchain_core.prompts import ChatPromptTemplate
prompt = ChatPromptTemplate.from_messages([
    ("system","you are a assistents"),
    ("user","{inputs}")
])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 3
#       1 # chatprompttemplets
#       2 from langchain_core.prompts import ChatPromptTemplate
# ----> 3 prompt = ChatPromptTemplate([
#       4     ()
#       5 ])
#
# File d:\AI-Worksspace\agentic-ai\langchain\venv\lib\site-packages\langchain_core\prompts\chat.py:972, in ChatPromptTemplate.__init__(self, messages, template_format, **kwargs)
#     903 def __init__(
#     904     self,
#     905     messages: Sequence[MessageLikeRepresentation],
#    (...)
#     908     **kwargs: Any,
#     909 ) -> None:
#     910     """Create a chat prompt template from a variety of message formats.
#     911
#     912     Args:
#    (...)
#     970         ```
#     971     """
# --> 972     messages_ = [
#     973         _convert_to_message_template(message, template_format)
#     974         for message in messages
#     975     ]
#     977     # Automatically infer input variables from messages
#     978     input_vars: set[str] = set()
#
# File d:\AI-Worksspace\agentic-ai\langchain\venv\lib\site-packages\langchain_core\prompts\chat.py:973, in <listcomp>(.0)
#     903 def __init__(
#     904     self,
#     905     messages: Sequence[MessageLikeRepresentation],
#    (...)
#     908     **kwargs: Any,
#     909 ) -> None:
#     910     """Create a chat prompt template from a variety of message formats.
#     911
#     912     Args:
#    (...)
#     970         ```
#     971     """
#     972     messages_ = [
# --> 973         _convert_to_message_template(message, template_format)
#     974         for message in messages
#     975     ]
#     977     # Automatically infer input variables from messages
#     978     input_vars: set[str] = set()
#
# File d:\AI-Worksspace\agentic-ai\langchain\venv\lib\site-packages\langchain_core\prompts\chat.py:1462, in _convert_to_message_template(message, template_format)
#    1460     if len(message) != 2:  # noqa: PLR2004
#    1461         msg = f"Expected 2-tuple of (role, template), got {message}"
# -> 1462         raise ValueError(msg)
#    1463     message_type_str, template = message
#    1465 if isinstance(message_type_str, str):
#
# ValueError: Expected 2-tuple of (role, template), got ()

# %%
# chain 
chain = prompt|model
chain.invoke({"inputs:What is ai"})

# %%
# stroutputs parse 
from langchain_core.output_parsers
